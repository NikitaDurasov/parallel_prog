# %%
import matplotlib.pyplot as plt 
from pylab import rcParams
# %matplotlib inline 
rcParams['figure.figsize'] = 10, 8

# %%
data10e7 = [(1, 1, 0.638, 0.638), (1, 1, 0.875, 0.871), (1, 1, 0.638, 0.638), (2, 1, 0.641, 0.641), (2, 1, 0.638, 0.637), (2, 1, 0.645, 0.644), (3, 0.999, 0.637, 0.638), (3, 1, 0.638, 0.638), (3, 1, 0.638, 0.638), (4, 0.999, 0.642, 0.643), (4, 0.991, 0.633, 0.638), (4, 0.999, 0.638, 0.638), (5, 0.994, 0.634, 0.637), (5, 0.996, 0.639, 0.642), (5, 0.998, 0.645, 0.646), (6, 1, 0.642, 0.642), (6, 1, 0.643, 0.642), (6, 0.997, 0.634, 0.636), (7, 0.997, 0.653, 0.655), (7, 0.995, 0.644, 0.648), (7, 0.996, 0.642, 0.644), (8, 0.998, 0.637, 0.638), (8, 0.994, 0.642, 0.646), (8, 0.998, 0.637, 0.638), (10, 0.998, 0.636, 0.638), (10, 0.998, 0.641, 0.642), (10, 0.999, 0.639, 0.639), (12, 0.994, 0.643, 0.647), (12, 0.996, 0.645, 0.648), (12, 0.996, 0.644, 0.647)]

# %%
plt.xlabel("Number of processes")
plt.ylabel("Speedup")
plt.scatter([x[0] for x in data10e7], [x[1] for x in data10e7])
plt.grid()

# %%
plt.xlabel("Number of processes")
plt.ylabel("Timing of simple integration")
plt.scatter([x[0] for x in data10e7[3:]], [x[2] for x in data10e7[3:]])
plt.grid()

# %%
data1000 = [(1, 0.972, 6.51e-05, 6.7e-05), (1, 0.93, 6.7e-05, 7.2e-05), (1, 0.882, 6.79e-05, 7.7e-05), (2, 0.635, 6.6e-05, 0.000104), (2, 0.667, 6.6e-05, 9.89e-05), (2, 0.627, 8.2e-05, 0.000131), (3, 0.676, 7.7e-05, 0.000114), (3, 0.369, 6.6e-05, 0.000179), (3, 0.541, 6.39e-05, 0.000118), (4, 0.433, 7.01e-05, 0.000162), (4, 0.404, 7.8e-05, 0.000193), (4, 0.598, 6.39e-05, 0.000107), (5, 0.142, 6.48e-05, 0.000457), (5, 0.12, 6.7e-05, 0.000558), (5, 0.133, 6.51e-05, 0.000491), (6, 0.0554, 6.6e-05, 0.00119), (6, 0.0479, 6.6e-05, 0.00138), (6, 0.057, 7.39e-05, 0.0013), (7, 0.024, 7.1e-05, 0.00296), (7, 0.0611, 6.79e-05, 0.00111), (7, 0.0465, 6.7e-05, 0.00144), (8, 0.045, 8.3e-05, 0.00184), (8, 0.0311, 6.39e-05, 0.00206), (8, 0.0393, 6.91e-05, 0.00176), (10, 0.0279, 6.58e-05, 0.00236), (10, 0.0392, 9.3e-05, 0.00237), (10, 0.0271, 6.51e-05, 0.0024), (12, 0.0214, 6.89e-05, 0.00322), (12, 0.0238, 6.79e-05, 0.00285), (12, 0.0219, 6.7e-05, 0.00306)]

# %%
plt.xlabel("Number of processes")
plt.ylabel("Speedup")
plt.scatter([x[0] for x in data1000], [x[1] for x in data1000])
plt.grid()

# %%
plt.xlabel("Number of processes")
plt.ylabel("Timing of simple integration")
plt.scatter([x[0] for x in data1000], [x[2] for x in data1000])
plt.grid()

# %%
data = [(2, 2, 0.592, 0.296), (2, 1.3, 0.59, 0.455), (2, 1.99, 0.587, 0.294), (3, 3, 0.594, 0.198), (3, 2.97, 0.587, 0.198), (3, 3, 0.588, 0.196), (4, 2.19, 0.605, 0.276), (4, 3.95, 0.592, 0.15), (4, 3.93, 0.59, 0.15), (5, 4.79, 0.615, 0.128), (5, 4.74, 0.607, 0.128), (5, 4.75, 0.607, 0.128), (6, 5.87, 0.589, 0.1), (6, 5.85, 0.608, 0.104), (6, 5.91, 0.59, 0.0998), (7, 6.74, 0.624, 0.0926), (7, 3.8, 0.612, 0.161), (7, 6.58, 0.609, 0.0926), (8, 7.87, 0.602, 0.0765), (8, 7.48, 0.589, 0.0788), (8, 7.78, 0.594, 0.0763), (10, 9.5, 0.594, 0.0625), (10, 9.44, 0.589, 0.0624), (10, 9.15, 0.61, 0.0667), (12, 10.7, 0.598, 0.0557), (12, 10.9, 0.605, 0.0557), (12, 8.2, 0.607, 0.074)]

# %%
plt.xlabel("Number of processes")
plt.ylabel("Speedup")
plt.scatter([x[0] for x in data], [x[1] for x in data])
plt.grid()
